# %% [markdown]
# # 📝 Unit 2 Assignment: Time Series Analysis
#
# **Objective:** Test your understanding of Classical (ARIMA) and Deep Learning (LSTM) approaches to Time Series forecasting.
#
# **Instructions:**
# 1.  Run the Data Generation cell to create the dataset.
# 2.  Complete the tasks in Parts 1, 2, and 3.
# 3.  Compare the results.

# %%
# 🛠️ DATA GENERATION (DO NOT CHANGE)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(123)
t = np.arange(0, 500)
trend = 0.1 * t
seasonality = 10 * np.sin(2 * np.pi * t / 50)
noise = np.random.normal(0, 2, len(t))
y = trend + seasonality + noise

df = pd.DataFrame({'Time': t, 'Value': y})
df.set_index('Time', inplace=True)

plt.figure(figsize=(10, 4))
plt.plot(df['Value'])
plt.title("Assignment Dataset")
plt.show()

# %% [markdown]
# ## Part 1: Conceptual Questions
#
# **1. What does it mean for a time series to be 'Stationary'? Why is it important for ARIMA?**

# %% [markdown]
# > *Write your answer here.*

# %% [markdown]
# **2. Explain the difference between the 'Forget Gate' and the 'Input Gate' in an LSTM.**

# %% [markdown]
# > *Write your answer here.*

# %% [markdown]
# ## Part 2: Classical Forecasting (ARIMA)
#
# **Task 2.1:** Check the stationarity of `df['Value']` using the Augmented Dickey-Fuller test. Is it stationary? If not, apply differencing.

# %%
# Your Code Here

# %% [markdown]
# **Task 2.2:** Fit an ARIMA model (you can choose orders $p,d,q$ manually or use auto_arima logic). Forecast the next 20 steps.

# %%
# Your Code Here

# %% [markdown]
# ## Part 3: Deep Learning Forecasting (LSTM)
#
# **Task 3.1:** Preprocess the data:
# 1.  Normalize the data using `MinMaxScaler`.
# 2.  Create sequences with a `window_size` of 10.

# %%
# Your Code Here

# %% [markdown]
# **Task 3.2:** Build and train an LSTM model. Predict the next steps and visualize the result.

# %%
# Your Code Here
