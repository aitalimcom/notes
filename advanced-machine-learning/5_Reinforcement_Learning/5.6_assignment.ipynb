# %% [markdown]
# # 📝 Unit 5 Assignment: Reinforcement Learning
#
# **Objective:** Implement Q-Learning for the Taxi-v3 environment.
#
# **Instructions:**
# 1.  Load the `Taxi-v3` environment using Gymnasium.
# 2.  Implement the Q-Learning algorithm.
# 3.  Train the agent for 1000 episodes.
# 4.  Evaluate the agent's performance.

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

env = gym.make("Taxi-v3", render_mode="ansi")

print("Action Space:", env.action_space)
print("State Space:", env.observation_space)

# %% [markdown]
# **Task 5.1:** Initialize the Q-Table with zeros.

# %%
# Your Code Here
# q_table = ...

# %% [markdown]
# **Task 5.2:** Implement the Q-Learning training loop.

# %%
alpha = 0.1
gamma = 0.6
epsilon = 0.1
episodes = 1000

# for i in range(episodes):
#     state, _ = env.reset()
#     ...
#     pass

# %% [markdown]
# **Task 5.3:** Test the trained agent for one episode and print the total reward.

# %%
# Your Code Here
