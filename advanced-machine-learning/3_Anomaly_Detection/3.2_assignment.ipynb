# %% [markdown]
# # 📝 Unit 3 Assignment: Anomaly Detection
#
# **Objective:** Build and compare Anomaly Detection models on a non-linear dataset.
#
# **Instructions:**
# 1.  Run the Data Generation cell.
# 2.  Implement Isolation Forest.
# 3.  Implement an Autoencoder.
# 4.  Compare the results.

# %%
# 🛠️ DATA GENERATION (DO NOT CHANGE)
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

# Generate Normal Data (Moons shape is non-linear)
X, _ = make_moons(n_samples=500, noise=0.05, random_state=42)

# Generate Anomalies (Random noise)
X_outliers = np.random.uniform(low=-1.5, high=2.5, size=(20, 2))
X = np.vstack([X, X_outliers])

plt.scatter(X[:, 0], X[:, 1], alpha=0.6)
plt.title("Assignment Dataset: Two Moons with Outliers")
plt.show()

# %% [markdown]
# ## Task 1: Isolation Forest
#
# 1.  Initialize `IsolationForest` (Experiment with `contamination` parameter).
# 2.  Fit and predict on `X`.
# 3.  Visualize the results (Color the points based on prediction).

# %%
# Your Code Here

# %% [markdown]
# ## Task 2: Autoencoder (Deep Learning)
#
# 1.  Scale the data using `StandardScaler`.
# 2.  Build a simple Autoencoder using Keras (Input -> Dense -> Bottleneck -> Dense -> Output).
# 3.  Train it on the data.
# 4.  Calculate Reconstruction Error (MSE).
# 5.  Set a threshold to identify outliers (e.g., top 5% highest errors).
# 6.  Visualize the results.

# %%
# Your Code Here

# %% [markdown]
# ## Task 3: Comparison
#
# Which method performed better on the 'Moon' shape? Why?

# %% [markdown]
# > *Write your answer here.*
